# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0;font-family:Times New Roman">LernKontrolle 21.10.2022</h1></center>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <hr>
#       <h4 style="font-family:courier;font-size:1.3em">
# Lade die CSV Datein 'Dataset.csv' herunter und speichere sie in einem gewünschten Ordner auf deinem Rechner.
# </h4>
# <hr>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#           <h4 style="font-family:courier;font-size:1.7em">
# Aufgabe1
# </h4>
#   <hr>
#       <h4 style="font-family:courier;font-size:1.5em">
# Bearbeite die unteren angegebenen Steps<br>
# </h4>
# </div>

# %% [markdown]
# # Step1
# ### Lese die  'dataset.csv' Datei  und speichere den Dataframe in der Variable 'data'. Gib anschließend die ersten 4 Zeilen des Dataframes aus

# %%
import pandas as pd
path = "/Users/michael/Downloads/Tagesaufgaben/Übungsaufgaben_Lösungen/"
data = pd.read_csv(path + "dataset_Lernkontrolle21102022.csv")
data.head()
# Out:
# /var/folders/ns/btcstnbj05gd9s1cnttlfqz80000gn/T/ipykernel_48267/1816651602.py:3: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path + "dataset_Lernkontrolle21102022.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# ...

# %%
#
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 103865  201510281024            8            otc alterations permit
# 151992  201703131363            8            otc alterations permit
# 92291   201507161675            3  additions alterations or repairs
# 177285  201706169592            8            otc alterations permit
# 72244   201501095369            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 103865           10/28/2015  1238  021            252                  NaN
# 151992           03/13/2017  1182  006           1330                  NaN
# 92291            07/16/2015  6580  018            456                  NaN
# 177285           06/16/2017  6657  063            225                  NaN
# 72244            01/09/2015  3705  042            865                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %% [markdown]
# # Step2
# ## Wie viel NaN hat jeder Spalte!?
# ### Gib anschließend die 10 größten Werte aus

# %%
#
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %%
# Anzahl NaN
data.isna().sum().nlargest(10)
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %% [markdown]
# # Step 3
# ### Lösche die Spalten wo die Null Werte 50%>

# %%
#
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# ...

# %%
# Null Werte 50%
# über isnull
data_50_prozent = data.drop(data.columns[data.isnull().mean() >0.5], axis=1)
data_50_prozent.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# ...

# %%
# Null Werte 50%
# über isna
data_50_2 = data[data.columns[data.isna().sum()/data.shape[0] < 0.5]] 
data_50_2.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# ...

# %% [markdown]
# # Step 4
# ### Prozentual gesehen, wie viel NaN Werte gibt es im ganzen DataFrame?

# %%
# 33.21120574926803
# Out:
# 33.21120574926803

# %%
# Anzahl NaN-Values für kompletten Dataframe
# für jede spalte
df_nur_na_spalten = data.isna().sum()
# Gesamt Anzahl Zellen in data 
df_zellenanzahl = data.size
Gesamtanzahl_fehlender_Werte = df_nur_na_spalten.sum()
Prozentsatz_fehlender_Werte = (Gesamtanzahl_fehlender_Werte * 100)/df_zellenanzahl
print(f"Prozentualer Anteil der NaNs im Datensatz : {Prozentsatz_fehlender_Werte}")
# Out:
# Prozentualer Anteil der NaNs im Datensatz : 26.260023150584026

# %%
# Anzahl NaN values für die 50% Daten
# für jede spalte
df_nur_na_spalten = data_50_2.isna().sum()
# Gesamt Anzahl Zellen in data 
df_zellenanzahl = data_50_2.size
Gesamtanzahl_fehlender_Werte = df_nur_na_spalten.sum()
Prozentsatz_fehlender_Werte = (Gesamtanzahl_fehlender_Werte * 100)/df_zellenanzahl
print(f"Prozentualer Anteil der NaNs im Datensatz : {Prozentsatz_fehlender_Werte}")
# Out:
# Prozentualer Anteil der NaNs im Datensatz : 9.136027563363204

# %%
# Kontrolle per Einzelschritte
#df_anzahl_nan_werte = 
data.isnull().sum().sum()
# Out:
# 2245941

# %%
# Gesamt Anzahl Zellen in data 
#df_zellenanzahl = 
data.size
# Out:
# 8552700

# %%
Prozentsatz_fehlender_Werte = (data.isnull().sum().sum() * 100) / data.size
print(f"Prozentualer Anteil der NaNs im Datensatz : {Prozentsatz_fehlender_Werte}")
# Out:
# Prozentualer Anteil der NaNs im Datensatz : 26.260023150584026

# %%
#df_anzahl_nan_werte = 
data_50_prozent.isna().sum().sum()
# Out:
# 617833

# %%
#df_zellenanzahl = 
data_50_prozent.size
# Out:
# 6762600

# %%
#Prozentsatz_fehlender_Werte = (df_anzahl_nan_werte * 100) / df_zellenanzahl
Prozentsatz_fehlender_Werte = (data_50_prozent.isna().sum().sum() * 100) / data_50_prozent.size
print(f"Prozentualer Anteil der NaNs im Datensatz : {Prozentsatz_fehlender_Werte}")
# Out:
# Prozentualer Anteil der NaNs im Datensatz : 9.136027563363204

# %% [markdown]
# # step 5
# ### Zeige mithilfe der missingno Library alle NaN Werte in einem Graphen an

# %%
#

# %%
# Import Library Missingno 
import missingno as msno
msno.matrix(data.drop(data.columns[data.isnull().mean() >0.5], axis=1))
# Out:
# <AxesSubplot: >

# %%
# Recherche

# %% [markdown]
# # Step6 (recherche Aufgabe)
# ## Fülle alle NaN Werte in der Spalte "Existing Use" mit dem nächsten darüber liegenden NICHT NaN Wert!
# ## Im zweiten Schritt, füllt die übrigen NaN Werte mit 0.
# ### Die beiden folgenden Tabellen sind Beispiele zur Veranschaulichung. Die erste zeigt die Ausgangstabelle und die zweite das Ergebnis nach Anwendung des zweiten Schrittes.

# %% [markdown]
# Spalte 1 | Spalte 2
# -------- | --------
# NaN   | 1
#  3  | NaN
# NaN | 7
# NaN   | NaN

# %% [markdown]
# ##### Endergebnis
# Spalte 1 | Spalte 2
# -------- | --------
# 0   | 1
#  3  | 1
# 3 | 7
# 3   | 7

# %%
#forward fill
NaN_Existing_Use_ffill = data_50_prozent["Existing Use"].fillna(method='ffill')
NaN_Existing_Use_ffill
# Out:
# 0         tourist hotel/motel
# 1         tourist hotel/motel
# 2                retail sales
# 3           1 family dwelling
# 4                retail sales
#                  ...
# 198895      2 family dwelling
# 198896             apartments
# 198897             apartments
# 198898             apartments
# 198899             apartments
# Name: Existing Use, Length: 198900, dtype: object

# %%
# restliche NaNs mit 0 füllen
NaN_Existing_Use_ffill_0 = NaN_Existing_Use_ffill.fillna(0)
NaN_Existing_Use_ffill_0
# Out:
# 0         tourist hotel/motel
# 1         tourist hotel/motel
# 2                retail sales
# 3           1 family dwelling
# 4                retail sales
#                  ...
# 198895      2 family dwelling
# 198896             apartments
# 198897             apartments
# 198898             apartments
# 198899             apartments
# Name: Existing Use, Length: 198900, dtype: object

# %%
# mit bfill
NaN_Existing_Use_bfill = data_50_prozent["Existing Use"].fillna(method='bfill')
NaN_Existing_Use_bfill_0 = NaN_Existing_Use_bfill.fillna(0)
NaN_Existing_Use_bfill_0
# Out:
# 0         tourist hotel/motel
# 1         tourist hotel/motel
# 2                retail sales
# 3           1 family dwelling
# 4                retail sales
#                  ...
# 198895             apartments
# 198896             apartments
# 198897                      0
# 198898                      0
# 198899                      0
# Name: Existing Use, Length: 198900, dtype: object

# %% [markdown]
# # Step 7
# ## Ersetze die NaN Werte in der Spalte "Number of Existing Stories"  mit einer 1

# %%
# 
data_NaN_als_1 = data["Number of Existing Stories"].fillna(1)
data_NaN_als_1
# Out:
# 0         6.0
# 1         7.0
# 2         6.0
# 3         2.0
# 4         3.0
#          ...
# 198895    1.0
# 198896    4.0
# 198897    1.0
# 198898    1.0
# 198899    1.0
# Name: Number of Existing Stories, Length: 198900, dtype: float64

# %% [markdown]
# # Step 8
# ## Ersetze die NaN Werte in der Spalte "Existing Units"  mit der Maximale Wert Diese Spalte

# %%
data_NaN_als_Max = data["Existing Units"].fillna(max(data["Existing Units"]))
data_NaN_als_Max
# Out:
# 0          143.0
# 1         1907.0
# 2           39.0
# 3            1.0
# 4         1907.0
#            ...
# 198895    1907.0
# 198896       4.0
# 198897    1907.0
# 198898    1907.0
# 198899    1907.0
# Name: Existing Units, Length: 198900, dtype: float64

# %% [markdown]
# # Step 9
# ## Ersetze die NaN Werte in der Spalte "Plansets"  mit eine Polynomial Interpolation  zweite Ordnung

# %%
import pandas as pd
import numpy as np
data_NaN_als_Poly2 = data["Plansets"].interpolate(method = "polynomial", order = 2)
data_NaN_als_Poly2
# Out:
# 0         2.000000
# 1         2.000000
# 2         2.000000
# 3         2.000000
# 4         2.000000
#             ...
# 198895    0.779835
# 198896    2.000000
# 198897         NaN
# 198898         NaN
# 198899         NaN
# Name: Plansets, Length: 198900, dtype: float64

# %% [markdown]
# # Step 10
# ### Lade die Aktualisierte Notebook Auf den Server (Github)

# %% [markdown]
# # GOOD LUCK !!!!!

# %%
# Danke!
